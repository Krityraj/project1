# %%
#============================
CLUSTERING

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\rajkr\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv("C:/Users/rajkr/OneDrive/Documents/clustering.csv")
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
#plot
plt.hist(df)
# Out:
# (array([[3.999e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [3.624e+03, 2.820e+02, 6.100e+01, 1.300e+01, 1.100e+01, 3.000e+00,
#          2.000e+00, 2.000e+00, 0.000e+00, 1.000e+00],
#         [3.999e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [3.999e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [3.999e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [3.999e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#         [3.991e+03, 8.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#          0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
# ...

# %%
#boxplot
plt.boxplot(df)
plt.show()

# %%
#correlation
correlation=df.corr()
correlation
# Out:
#                         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# ID#                1.000000 -0.243737   -0.019374  -0.224465   0.020291
# Balance           -0.243737  1.000000    0.108722   0.338344  -0.008804
# Qual_miles        -0.019374  0.108722    1.000000   0.007931  -0.013923
# cc1_miles         -0.224465  0.338344    0.007931   1.000000  -0.068223
# cc2_miles          0.020291 -0.008804   -0.013923  -0.068223   1.000000
# cc3_miles         -0.014707  0.035243   -0.007779   0.060555  -0.006166
# Bonus_miles       -0.203012  0.403487    0.031021   0.825200  -0.003969
# Bonus_trans       -0.146915  0.324935    0.050725   0.608943   0.064399
# Flight_miles_12mo -0.031013  0.217551    0.126774   0.037370   0.010598
# Flight_trans_12   -0.052096  0.255700    0.144004   0.041333   0.028284
# Days_since_enroll -0.964988  0.263129    0.017312   0.230849  -0.005807
# Award?            -0.177901  0.178494    0.095256   0.335457   0.005332
#
# ...

# %%
#heatmap
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
#Linkage
X=df.iloc[:,2:4].values
X
X.shape
# Out:
# (3999, 2)

# %%
#scatter plot
plt.scatter(X[:,0],X[:,1],color='red')
plt.ylabel('Qual_miles')
plt.xlabel('cc1_miles')
plt.show()

# %%
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7)) 
plt.title('Dendrogram')
dend=shc.dendrogram(shc.linkage(X,method='single'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster=AgglomerativeClustering(n_clusters=7,affinity='euclidean',linkage='single')
Y=cluster.fit_predict(X)
Y_new=pd.DataFrame(Y)
Y_new[0].value_counts()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# 0
# 2    3945
# 6      33
# 0      13
# 1       4
# 5       2
# 3       1
# 4       1
# Name: count, dtype: int64

# %%
#scatterplot
plt.figure(figsize=(10,7))
plt.scatter(X[:,0],X[:,1],c=cluster.labels_,cmap='rainbow')

# %%
'''AS we can see that single linkage is not giving a better result because one cluster
is getting maximum linkage and other clusters is geeting few linkages which
is not balancing the data.So we have other options for better results'''
# Out:
# 'AS we can see that single linkage is not giving a better result because one cluster\nis getting maximum linkage and other clusters is geeting few linkages which\nis not balancing the data.So we have other options for better results'

# %%
#b)
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7)) 
plt.title('Dendrogram')
dend=shc.dendrogram(shc.linkage(X,method='complete'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster=AgglomerativeClustering(n_clusters=7,affinity='euclidean',linkage='complete')
Y=cluster.fit_predict(X)
Y_new=pd.DataFrame(Y)
Y_new[0].value_counts()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# 0
# 0    3887
# 4      58
# 3      17
# 6      16
# 2       9
# 5       8
# 1       4
# Name: count, dtype: int64

# %%
#scatterplot
plt.figure(figsize=(10,7))
plt.scatter(X[:,0],X[:,1],c=cluster.labels_,cmap='rainbow')

# %%
'''AS we can see that there is improvement then single linkage but still
not giving the balance in the dataset.So we will do further analysis to make data appropriate'''
# Out:
# 'AS we can see that there is improvement then single linkage but still\nnot giving the balance in the dataset.So we will do further analysis to make data appropriate'

# %%
#b) DBscan clustering


X1=df.iloc[:,2:4].values
X1
# Out:
# array([[0, 1],
#        [0, 1],
#        [0, 1],
#        ...,
#        [0, 3],
#        [0, 1],
#        [0, 1]], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_X=SS.fit_transform(X1)

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN(eps=1.2,min_samples=800)
dbscan.fit(SS_X)
# Out:
# DBSCAN(eps=1.2, min_samples=800)

# %%
Y=dbscan.labels_
pd.DataFrame(Y).value_counts()
# Out:
# 0
#  0    3875
# -1     124
# Name: count, dtype: int64

# %%
#Create a new columns:-
df['cluster']=pd.DataFrame(Y)
df.head()
df.tail()
noise_points=df[df['cluster']==-1]   
noise_points

final_data=df[df['cluster']==0]
final_data

t=df['cluster'].value_counts()
t
# Out:
# cluster
#  0    3875
# -1     124
# Name: count, dtype: int64
