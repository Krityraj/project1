# %%
#MLR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\rajkr\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("C:/Users/rajkr/OneDrive/Documents/a2.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.head()
# Out:
#    Price  Age_08_04     KM Fuel_Type  HP  Automatic    cc  Doors  Cylinders  \
# 0  13500         23  46986    Diesel  90          0  2000      3          4
# 1  13750         23  72937    Diesel  90          0  2000      3          4
# 2  13950         24  41711    Diesel  90          0  2000      3          4
# 3  14950         26  48000    Diesel  90          0  2000      3          4
# 4  13750         30  38500    Diesel  90          0  2000      3          4
#
#    Gears  Weight
# 0      5    1165
# 1      5    1165
# 2      5    1165
# 3      5    1165
# 4      5    1170

# %%
df.shape
# Out:
# (1436, 11)

# %%
plt.scatter(x=df['Age_08_04'],y=df['Price'])
plt.xlabel('Age_08_04')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(x=df['KM'],y=df['Price'])
plt.xlabel('KM')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(x=df['Automatic'],y=df['Price'])
plt.xlabel('Automatic')
plt.ylabel('Price')
plt.show()

# %%
t1=df['Price'].value_counts()
t1
t1.plot(kind='bar')
# Out:
# <Axes: xlabel='Price'>

# %%
df['Price'].hist()
# Out:
# <Axes: >

# %%
df['Age_08_04'].hist()
# Out:
# <Axes: >

# %%
df['KM'].hist()
# Out:
# <Axes: >

# %%
sns.heatmap(data=df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
# !pip install autoviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV= AutoViz_Class()
filename= 'C:/Users/rajkr/OneDrive/Documents/a2.csv'
sep=","
dft= AV.AutoViz(filename,sep=",",depVar="",dfte=None,header=0,verbose=0,lowess=False,chart_format="svg",max_rows_analyzed=1436,max_cols_analyzed=11,)
# Out:
# Imported v0.1.904. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (1436, 11)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     11 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
# Since Number of Rows in data 1436 exceeds maximum, randomly sampling 1436 rows for EDA...
# There are 1 duplicate rows in your dataset
# ...

# %%
df.dtypes
# Out:
# Price         int64
# Age_08_04     int64
# KM            int64
# Fuel_Type    object
# HP            int64
# Automatic     int64
# cc            int64
# Doors         int64
# Cylinders     int64
# Gears         int64
# Weight        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
#Apply transformation
df.dtypes
df1=df['Fuel_Type']
df1
from sklearn.preprocessing import LabelEncoder
LE= LabelEncoder()
df['Fuel_Type']=LE.fit_transform(df['Fuel_Type'])
df['Fuel_Type']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1431    2
# 1432    2
# 1433    2
# 1434    2
# 1435    2
# Name: Fuel_Type, Length: 1436, dtype: int32

# %%
#split
X=df.iloc[:,1:12]
Y=df['Price']
Y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1436, dtype: int64

# %%
#data partition
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y)

# %%
#modelfitting
from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#modelprediction

y_pred_train=LR.predict(X_train)
y_pred_test=LR.predict(X_test)

# %%
#metrics
from sklearn.metrics import mean_squared_error
err1=np.sqrt(mean_squared_error(Y_train,y_pred_train))
print('Training Error:',(err1).round(2))
err2=np.sqrt(mean_squared_error(Y_test,y_pred_test))
print('Test Error:',(err2).round(2))
# Out:
# Training Error: 1352.1
# Test Error: 1503.96

# %%
#Apply validation
Training_err= []
Test_err= []
for i in range(1,1001):
    X_Train,X_Test,Y_Train,Y_Test= train_test_split(X,Y,train_size=0.75,random_state=i)
    LR.fit(X_train,Y_train)
    y_pred_train =LR.predict(X_train)
    y_pred_test =LR.predict(X_test)
    Training_err.append(mean_squared_error(Y_train,y_pred_train))
    Test_err.append(mean_squared_error(Y_test,y_pred_test))
    print("Average Training Error",np.sqrt(np.mean(Training_err)).round(3))
    print("Average Test Error",np.sqrt(np.mean(Test_err)).round(3))
# Out:
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# Average Test Error 1503.965
# Average Training Error 1352.097
# ...

# %%
#Ridge and lasso regression

from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(X,Y)

from sklearn.linear_model import Ridge
RR =Ridge(alpha=1.0)
RR.fit(X,Y)

RR.coef_
list(X)
d1=pd.DataFrame(list(X))
d1
d2=pd.DataFrame(LR.coef_)
d2
d3=pd.DataFrame(RR.coef_)
d3
pd.concat([d1,d2,d3],axis=1)
# Out:
#            0             0           0
# 0  Age_08_04 -1.237829e+02 -123.767111
# 1         KM -1.753825e-02   -0.017556
# 2  Fuel_Type  5.777178e+02  571.905740
# 3         HP  2.366908e+01   23.759241
# 4  Automatic  3.020992e+02  297.595986
# 5         cc -5.693481e-02   -0.057254
# 6      Doors -2.991783e+01  -30.237307
# 7  Cylinders -1.136868e-12    0.000000
# 8      Gears  6.220168e+02  608.742827
# 9     Weight  2.077316e+01   20.757106

# %%
from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(X,Y)

from sklearn.linear_model import Ridge
RR =Ridge(alpha=3.0)
RR.fit(X,Y)

RR.coef_
list(X)
d1=pd.DataFrame(list(X))
d1
d2=pd.DataFrame(LR.coef_)
d2
d3=pd.DataFrame(RR.coef_)
d3
pd.concat([d1,d2,d3],axis=1)
# Out:
#            0             0           0
# 0  Age_08_04 -1.237829e+02 -123.736516
# 1         KM -1.753825e-02   -0.017592
# 2  Fuel_Type  5.777178e+02  560.574119
# 3         HP  2.366908e+01   23.931955
# 4  Automatic  3.020992e+02  289.046282
# 5         cc -5.693481e-02   -0.057880
# 6      Doors -2.991783e+01  -30.816054
# 7  Cylinders -1.136868e-12    0.000000
# 8      Gears  6.220168e+02  583.843939
# 9     Weight  2.077316e+01   20.725471

# %%
from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(X,Y)

from sklearn.linear_model import Ridge
RR =Ridge(alpha=5)
RR.fit(X,Y)

RR.coef_
list(X)
d1=pd.DataFrame(list(X))
d1
d2=pd.DataFrame(LR.coef_)
d2
d3=pd.DataFrame(RR.coef_)
d3
pd.concat([d1,d2,d3],axis=1)
# Out:
#            0             0           0
# 0  Age_08_04 -1.237829e+02 -123.707223
# 1         KM -1.753825e-02   -0.017626
# 2  Fuel_Type  5.777178e+02  549.623933
# 3         HP  2.366908e+01   24.095287
# 4  Automatic  3.020992e+02  281.049921
# 5         cc -5.693481e-02   -0.058488
# 6      Doors -2.991783e+01  -31.323807
# 7  Cylinders -1.136868e-12    0.000000
# 8      Gears  6.220168e+02  560.923975
# 9     Weight  2.077316e+01   20.694518

# %%
#Lasso
from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(X,Y)

from sklearn.linear_model import Lasso
LA =Lasso(alpha=1.0)
LA.fit(X,Y)

LA.coef_
list(X)
d1=pd.DataFrame(list(X))
d1
d2=pd.DataFrame(LA.coef_)
d2
d3=pd.DataFrame(RR.coef_)
d3
pd.concat([d1,d2,d3],axis=1)
# Out:
#            0           0           0
# 0  Age_08_04 -123.718956 -123.707223
# 1         KM   -0.017596   -0.017626
# 2  Fuel_Type  563.426274  549.623933
# 3         HP   23.872242   24.095287
# 4  Automatic  281.674537  281.049921
# 5         cc   -0.057294   -0.058488
# 6      Doors  -29.596623  -31.323807
# 7  Cylinders    0.000000    0.000000
# 8      Gears  590.696649  560.923975
# 9     Weight   20.732730   20.694518

# %%
from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(X,Y)

from sklearn.linear_model import Lasso
LA =Lasso(alpha=3.0)
LA.fit(X,Y)

LA.coef_
list(X)
d1=pd.DataFrame(list(X))
d1
d2=pd.DataFrame(LA.coef_)
d2
d3=pd.DataFrame(RR.coef_)
d3
pd.concat([d1,d2,d3],axis=1)
# Out:
#            0           0           0
# 0  Age_08_04 -123.591011 -123.707223
# 1         KM   -0.017710   -0.017626
# 2  Fuel_Type  534.843470  549.623933
# 3         HP   24.278561   24.095287
# 4  Automatic  240.825130  281.049921
# 5         cc   -0.058013   -0.058488
# 6      Doors  -28.954234  -31.323807
# 7  Cylinders    0.000000    0.000000
# 8      Gears  528.056221  560.923975
# 9     Weight   20.651866   20.694518

# %%
from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(X,Y)

from sklearn.linear_model import Lasso
LA =Lasso(alpha=5.0)
LA.fit(X,Y)

LA.coef_
list(X)
d1=pd.DataFrame(list(X))
d1
d2=pd.DataFrame(LA.coef_)
d2
d3=pd.DataFrame(RR.coef_)
d3
pd.concat([d1,d2,d3],axis=1)
# Out:
#            0           0           0
# 0  Age_08_04 -123.463064 -123.707223
# 1         KM   -0.017825   -0.017626
# 2  Fuel_Type  506.260688  549.623933
# 3         HP   24.684879   24.095287
# 4  Automatic  199.975702  281.049921
# 5         cc   -0.058732   -0.058488
# 6      Doors  -28.311850  -31.323807
# 7  Cylinders    0.000000    0.000000
# 8      Gears  465.415790  560.923975
# 9     Weight   20.571003   20.694518

# %%
from sklearn.linear_model import LinearRegression
LR= LinearRegression()
LR.fit(X,Y)

from sklearn.linear_model import Lasso
LA =Lasso(alpha=7.0)
LA.fit(X,Y)

LA.coef_
list(X)
d1=pd.DataFrame(list(X))
d1
d2=pd.DataFrame(LA.coef_)
d2
d3=pd.DataFrame(RR.coef_)
d3
pd.concat([d1,d2,d3],axis=1)
# Out:
#            0           0           0
# 0  Age_08_04 -123.335117 -123.707223
# 1         KM   -0.017939   -0.017626
# 2  Fuel_Type  477.677906  549.623933
# 3         HP   25.091197   24.095287
# 4  Automatic  159.126274  281.049921
# 5         cc   -0.059451   -0.058488
# 6      Doors  -27.669465  -31.323807
# 7  Cylinders    0.000000    0.000000
# 8      Gears  402.775360  560.923975
# 9     Weight   20.490140   20.694518

# %%
#drop
X_new = X.drop(X.columns[[1,5,7]],axis=1)
X_new
X_new.shape
# Out:
# (1436, 7)

# %%
#final
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(X_new,Y)
LR.intercept_
LR.coef_
# Out:
# array([-142.8566799 , 1333.18048433,   27.74085428,  469.4972484 ,
#         -63.07721448,  380.61323629,   20.55556428])

# %%
#test
np.min(X_new)
np.max(X_new)
t1=np.array([[20,1,100,1,4,5,1200]])
LR.predict(t1)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# C:\ProgramData\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([17723.76454619])
