# %%
#================================
PCA

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\rajkr\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv("C:/Users/rajkr/OneDrive/Documents/PCA.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.head()
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
df.info()#for null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
#Visualisation
#Histogram
df['Type'].hist()
plt.hist(df)
# Out:
# (array([[178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [178.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
# ...

# %%
#boxplot
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x205f087d7b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x205f087dcf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x205f087d4b0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x205f087e230>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x205f087e4d0>,
# ...
#  'means': []}

# %%
#STRIP PLOT
sns.stripplot(df)
# Out:
# <Axes: >

# %%
#describe
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
#correlation
correlation=df.corr()
correlation
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %%
#heatmap
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
#split
X=df.iloc[:,1:14]
X
Y=df['Type']
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Type, Length: 178, dtype: int64

# %%
#Standardisation

from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_X=SS.fit_transform(X)

from sklearn.preprocessing import LabelEncoder
LE= LabelEncoder()
df['Type']=LE.fit_transform(df['Type'])
df['Type']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: Type, Length: 178, dtype: int64

# %%
pd.set_option('display.float_format',lambda x:'%.5f'%x)

# %%
#Load decomposition to do PCA analysis with sklearn
from sklearn.decomposition import PCA
pca=PCA()
PC=pca.fit_transform(SS_X)
pd.DataFrame(PC)
# Out:
#           0        1        2        3        4        5        6        7   \
# 0    3.31675 -1.44346 -0.16574 -0.21563  0.69304 -0.22388  0.59643  0.06514
# 1    2.20946  0.33339 -2.02646 -0.29136 -0.25765 -0.92712  0.05378  1.02442
# 2    2.51674 -1.03115  0.98282  0.72490 -0.25103  0.54928  0.42421 -0.34422
# 3    3.75707 -2.75637 -0.17619  0.56798 -0.31184  0.11443 -0.38334  0.64359
# 4    1.00891 -0.86983  2.02669 -0.40977  0.29846 -0.40652  0.44407  0.41670
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 173 -3.37052 -2.21629 -0.34257  1.05853 -0.57416 -1.10879  0.95842 -0.14610
# 174 -2.60196 -1.75723  0.20758  0.34950  0.25506 -0.02647  0.14689 -0.55243
# 175 -2.67784 -2.76090 -0.94094  0.31203  1.27136  0.27307  0.67924  0.04702
# 176 -2.38702 -2.29735 -0.55070 -0.68828  0.81396  1.17878  0.63398  0.39083
# 177 -3.20876 -2.76892  1.01391  0.59690 -0.89519  0.29609  0.00574 -0.29291
#
#           8        9        10       11       12
# ...

# %%
df1=pd.DataFrame(pca.explained_variance_ratio_)
df1
# Out:
#          0
# 0  0.36199
# 1  0.19207
# 2  0.11124
# 3  0.07069
# 4  0.06563
# 5  0.04936
# 6  0.04239
# 7  0.02681
# 8  0.02222
# 9  0.01930
# 10 0.01737
# 11 0.01298
# 12 0.00795

# %%
df1.iloc[0:1,]*100
df1.iloc[1:2]*100
df1.iloc[2:3]*100
df1.iloc[0:2]*100
# Out:
#          0
# 0 36.19885
# 1 19.20749

# %%
X1=PC[:,0:2]
X1
# Out:
# array([[ 3.31675081, -1.44346263],
#        [ 2.20946492,  0.33339289],
#        [ 2.51674015, -1.0311513 ],
#        [ 3.75706561, -2.75637191],
#        [ 1.00890849, -0.86983082],
#        [ 3.05025392, -2.12240111],
#        [ 2.44908967, -1.17485013],
#        [ 2.05943687, -1.60896307],
#        [ 2.5108743 , -0.91807096],
#        [ 2.75362819, -0.78943767],
#        [ 3.47973668, -1.30233324],
#        [ 1.7547529 , -0.61197723],
#        [ 2.11346234, -0.67570634],
#        [ 3.45815682, -1.13062988],
#        [ 4.31278391, -2.09597558],
#        [ 2.3051882 , -1.66255173],
#        [ 2.17195527, -2.32730534],
#        [ 1.89897118, -1.63136888],
#        [ 3.54198508, -2.51834367],
#        [ 2.0845222 , -1.06113799],
#        [ 3.12440254, -0.78689711],
#        [ 1.08657007, -0.24174355],
#        [ 2.53522408,  0.09184062],
#        [ 1.64498834,  0.51627893],
#        [ 1.76157587,  0.31714893],
#        [ 0.9900791 , -0.94066734],
#        [ 1.77527763, -0.68617513],
# ...

# %%
#Model fitting
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(X1,Y)
# Out:
# LogisticRegression()

# %%
#model prediction
y_pred=logreg.predict(X1)

# %%
#Metrics
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(Y,y_pred)
cm
ac1=accuracy_score(Y,y_pred)
ac1
# Out:
# 0.9662921348314607

# %%
# we are getting a very good accuracy score of 0.96.

#lets try it with cluster analysis and check the accuracy
 
#cluster analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
X=df.iloc[:,1:3]
X
# Out:
#      Alcohol   Malic
# 0   14.23000 1.71000
# 1   13.20000 1.78000
# 2   13.16000 2.36000
# 3   14.37000 1.95000
# 4   13.24000 2.59000
# ..       ...     ...
# 173 13.71000 5.65000
# 174 13.40000 3.91000
# 175 13.27000 4.28000
# 176 13.17000 2.59000
# 177 14.13000 4.10000
#
# [178 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_X=SS.fit_transform(X)

# %%
#Scatter plot
plt.scatter(SS_X[:,0],SS_X[:,1],color='green')
plt.ylabel('Alcohol')
plt.xlabel('Malic')
plt.show()

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title('Dendrogram')
dend=shc.dendrogram(shc.linkage(SS_X,method='single'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='single')
Y=cluster.fit_predict(SS_X)
Y_new=pd.DataFrame(Y)
Y_new[0].value_counts()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# 0
# 0    173
# 1      2
# 2      1
# 3      1
# 4      1
# Name: count, dtype: int64

# %%
#scatterplot
plt.figure(figsize=(10,7))
plt.scatter(SS_X[:,0],SS_X[:,1],c=cluster.labels_,cmap='rainbow')

# %%
#Single linkage is not giving the proper result as one data contains maximum values and others contains very few values

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title('Dendrogram')
dend=shc.dendrogram(shc.linkage(SS_X,method='complete'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='complete')
Y=cluster.fit_predict(SS_X)
Y_new=pd.DataFrame(Y)
Y_new[0].value_counts()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# 0
# 0    60
# 2    46
# 3    36
# 1    30
# 4     6
# Name: count, dtype: int64

# %%
#scatterplot
plt.figure(figsize=(10,7))
plt.scatter(SS_X[:,0],SS_X[:,1],c=cluster.labels_,cmap='rainbow')

# %%
#so from complete linkage we are getting the good result as the data is divided in a balancing way
#still for more results to see we can go with DBscan

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN(eps=0.75,min_samples=45)
dbscan.fit(SS_X)
# Out:
# DBSCAN(eps=0.75, min_samples=45)

# %%
Y=dbscan.labels_
pd.DataFrame(Y).value_counts()
# Out:
# 0
# -1    78
#  0    59
#  1    41
# Name: count, dtype: int64

# %%
#create a new data frame
df['cluster']=pd.DataFrame(Y)
df.head()
# Out:
#    Type  Alcohol   Malic     Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     0 14.23000 1.71000 2.43000    15.60000        127  2.80000     3.06000
# 1     0 13.20000 1.78000 2.14000    11.20000        100  2.65000     2.76000
# 2     0 13.16000 2.36000 2.67000    18.60000        101  2.80000     3.24000
# 3     0 14.37000 1.95000 2.50000    16.80000        113  3.85000     3.49000
# 4     0 13.24000 2.59000 2.87000    21.00000        118  2.80000     2.69000
#
#    Nonflavanoids  Proanthocyanins   Color     Hue  Dilution  Proline  cluster
# 0        0.28000          2.29000 5.64000 1.04000   3.92000     1065        0
# 1        0.26000          1.28000 4.38000 1.05000   3.40000     1050        0
# 2        0.30000          2.81000 5.68000 1.03000   3.17000     1185        0
# 3        0.24000          2.18000 7.80000 0.86000   3.45000     1480        0
# 4        0.39000          1.82000 4.32000 1.04000   2.93000      735       -1

# %%
df.tail()
# Out:
#      Type  Alcohol   Malic     Ash  Alcalinity  Magnesium  Phenols  \
# 173     2 13.71000 5.65000 2.45000    20.50000         95  1.68000
# 174     2 13.40000 3.91000 2.48000    23.00000        102  1.80000
# 175     2 13.27000 4.28000 2.26000    20.00000        120  1.59000
# 176     2 13.17000 2.59000 2.37000    20.00000        120  1.65000
# 177     2 14.13000 4.10000 2.74000    24.50000         96  2.05000
#
#      Flavanoids  Nonflavanoids  Proanthocyanins    Color     Hue  Dilution  \
# 173     0.61000        0.52000          1.06000  7.70000 0.64000   1.74000
# 174     0.75000        0.43000          1.41000  7.30000 0.70000   1.56000
# 175     0.69000        0.43000          1.35000 10.20000 0.59000   1.56000
# 176     0.68000        0.53000          1.46000  9.30000 0.60000   1.62000
# 177     0.76000        0.56000          1.35000  9.20000 0.61000   1.60000
#
#      Proline  cluster
# 173      740       -1
# 174      750       -1
# 175      835       -1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
#  14  cluster          178 non-null    int64
# dtypes: float64(11), int64(4)
# memory usage: 21.0 KB

# %%
#Lets check the accuracy in PCA

# %%
#split
X=df.iloc[:,1:14]
X
Y=df['cluster']
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4     -1
#       ..
# 173   -1
# 174   -1
# 175   -1
# 176   -1
# 177   -1
# Name: cluster, Length: 178, dtype: int64

# %%
#Standardisation

from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
SS_X=SS.fit_transform(X)

from sklearn.preprocessing import LabelEncoder
LE= LabelEncoder()
df['cluster']=LE.fit_transform(df['cluster'])
df['cluster']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 173    0
# 174    0
# 175    0
# 176    0
# 177    0
# Name: cluster, Length: 178, dtype: int64

# %%
pd.set_option('display.float_format',lambda x:'%.5f'%x)

# %%
#Load decomposition to do PCA analysis with sklearn
from sklearn.decomposition import PCA
pca=PCA()
PC=pca.fit_transform(SS_X)
pd.DataFrame(PC)
# Out:
#           0        1        2        3        4        5        6        7   \
# 0    3.31675 -1.44346 -0.16574 -0.21563  0.69304 -0.22388  0.59643  0.06514
# 1    2.20946  0.33339 -2.02646 -0.29136 -0.25765 -0.92712  0.05378  1.02442
# 2    2.51674 -1.03115  0.98282  0.72490 -0.25103  0.54928  0.42421 -0.34422
# 3    3.75707 -2.75637 -0.17619  0.56798 -0.31184  0.11443 -0.38334  0.64359
# 4    1.00891 -0.86983  2.02669 -0.40977  0.29846 -0.40652  0.44407  0.41670
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 173 -3.37052 -2.21629 -0.34257  1.05853 -0.57416 -1.10879  0.95842 -0.14610
# 174 -2.60196 -1.75723  0.20758  0.34950  0.25506 -0.02647  0.14689 -0.55243
# 175 -2.67784 -2.76090 -0.94094  0.31203  1.27136  0.27307  0.67924  0.04702
# 176 -2.38702 -2.29735 -0.55070 -0.68828  0.81396  1.17878  0.63398  0.39083
# 177 -3.20876 -2.76892  1.01391  0.59690 -0.89519  0.29609  0.00574 -0.29291
#
#           8        9        10       11       12
# ...

# %%
df1=pd.DataFrame(pca.explained_variance_ratio_)
df1
# Out:
#          0
# 0  0.36199
# 1  0.19207
# 2  0.11124
# 3  0.07069
# 4  0.06563
# 5  0.04936
# 6  0.04239
# 7  0.02681
# 8  0.02222
# 9  0.01930
# 10 0.01737
# 11 0.01298
# 12 0.00795

# %%
df1.iloc[0:1,]*100
df1.iloc[1:2]*100
df1.iloc[2:3]*100
df1.iloc[0:2]*100
# Out:
#          0
# 0 36.19885
# 1 19.20749

# %%
X1=PC[:,0:2]
X1
# Out:
# array([[ 3.31675081, -1.44346263],
#        [ 2.20946492,  0.33339289],
#        [ 2.51674015, -1.0311513 ],
#        [ 3.75706561, -2.75637191],
#        [ 1.00890849, -0.86983082],
#        [ 3.05025392, -2.12240111],
#        [ 2.44908967, -1.17485013],
#        [ 2.05943687, -1.60896307],
#        [ 2.5108743 , -0.91807096],
#        [ 2.75362819, -0.78943767],
#        [ 3.47973668, -1.30233324],
#        [ 1.7547529 , -0.61197723],
#        [ 2.11346234, -0.67570634],
#        [ 3.45815682, -1.13062988],
#        [ 4.31278391, -2.09597558],
#        [ 2.3051882 , -1.66255173],
#        [ 2.17195527, -2.32730534],
#        [ 1.89897118, -1.63136888],
#        [ 3.54198508, -2.51834367],
#        [ 2.0845222 , -1.06113799],
#        [ 3.12440254, -0.78689711],
#        [ 1.08657007, -0.24174355],
#        [ 2.53522408,  0.09184062],
#        [ 1.64498834,  0.51627893],
#        [ 1.76157587,  0.31714893],
#        [ 0.9900791 , -0.94066734],
#        [ 1.77527763, -0.68617513],
# ...

# %%
#Model fitting
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(X1,Y)
# Out:
# LogisticRegression()

# %%
#model prediction
y_pred=logreg.predict(X1)

# %%
#Metrics
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(Y,y_pred)
cm
ac1=accuracy_score(Y,y_pred)
ac1
# Out:
# 0.6966292134831461

# %%
#here we are getting the accuray score as 0.69

#So we can say that according to the dataset accuracy the previous model of PCA was good with accuracy of 0.96
